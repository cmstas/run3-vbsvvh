# %%
import ROOT as r
r.EnableImplicitMT()
import pandas as pd
pd.set_option('display.max_colwidth', None)

import numpy as np
import matplotlib.pyplot as plt

import mplhep as hep
hep.style.use(hep.style.CMS)

# %%
df_bkg = r.RDataFrame("Events", "/data/userdata/aaarora/vbsvvhAnalysis/preselection/OneLep2FJ/bkg.root")
df_sig = r.RDataFrame("Events", "/data/userdata/aaarora/vbsvvhAnalysis/preselection/OneLep2FJ/sig.root")

# %%
s = df_sig.Sum("weight").GetValue()
b = df_bkg.Sum("weight").GetValue()

# %%
s / np.sqrt(b)
# Out:
# np.float64(0.02438062179123976)

# %%
pdf = pd.DataFrame(df_sig.AsNumpy(["vbs1_pt", "vbs2_pt", "vbs1_eta", "vbs2_eta", "vbs1_phi", "vbs2_phi", "vbs1_mass", "vbs2_mass", "vbs_pt", "vbs_deta", "vbs_dphi", "vbs_m", "vbs_score", "weight"]))

# %%
pdf.weight.sum()
# Out:
# np.float64(7.13096983803326)

# %%
pdf[pdf["vbs_score"] > 0.4]["vbs2_eta"].hist(bins=50)
# Out:
# <Axes: >

# %%
pdf[pdf["vbs_score"] > 0.4].weight.sum()
# Out:
# np.float64(5.2899071801177335)
